# %%
import streamlit as st
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
df=pd.read_csv("https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/Startup.csv",sep=",")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# 15  114523.61       122616.84        261776.23  129917.04
# 16   78013.11       121597.55        264346.06  126992.93
# 17   94657.16       145077.58        282574.31  125370.37
# 18   91749.16       114175.79        294919.57  124266.90
# 19   86419.70       153514.11             0.00  122776.86
# 20   76253.86       113867.30        298664.47  118474.03
# 21   78389.47       153773.43        299737.29  111313.02
# 22   73994.56       122782.75        303319.26  110352.25
# 23   67532.53       105751.03        304768.73  108733.99
# 24   77044.01        99281.34        140574.81  108552.04
# 25   64664.71       139553.16        137962.62  107404.34
# 26   75328.87       144135.98        134050.07  105733.54
# 27   72107.60       127864.55        353183.81  105008.31
# 28   66051.52       182645.56        118148.20  103282.38
# 29   65605.48       153032.06        107138.38  101004.64
# 30   61994.48       115641.28         91131.24   99937.59
# 31   61136.38       152701.92         88218.23   97483.56
# 32   63408.86       129219.61         46085.25   97427.84
# 33   55493.95       103057.49        214634.81   96778.92
# 34   46426.07       157693.92        210797.67   96712.80
# 35   46014.02        85047.44        205517.64   96479.51
# 36   28663.76       127056.21        201126.82   90708.19
# 37   44069.95        51283.14        197029.42   89949.14
# 38   20229.59        65947.93        185265.10   81229.06
# 39   38558.51        82982.09        174999.30   81005.76
# 40   28754.33       118546.05        172795.67   78239.91
# 41   27892.92        84710.77        164470.71   77798.83
# 42   23640.93        96189.63        148001.11   71498.49
# 43   15505.73       127382.30         35534.17   69758.98
# 44   22177.74       154806.14         28334.72   65200.33
# 45    1000.23       124153.04          1903.93   64926.08
# 46    1315.46       115816.21        297114.46   49490.75
# 47       0.00       135426.92             0.00   42559.73
# 48     542.05        51743.15             0.00   35673.41
# 49       0.00       116983.80         45173.06   14681.40

# %%
X=df.drop(columns='Profit') #tolgo la colonna profit dal df perchè la mia x sarà composta dalle prime tre colonne
y=df['Profit']#questa sarà la mia y

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# 19   86419.70       153514.11             0.00
# 20   76253.86       113867.30        298664.47
# 21   78389.47       153773.43        299737.29
# 22   73994.56       122782.75        303319.26
# 23   67532.53       105751.03        304768.73
# 24   77044.01        99281.34        140574.81
# 25   64664.71       139553.16        137962.62
# 26   75328.87       144135.98        134050.07
# 27   72107.60       127864.55        353183.81
# 28   66051.52       182645.56        118148.20
# 29   65605.48       153032.06        107138.38
# 30   61994.48       115641.28         91131.24
# 31   61136.38       152701.92         88218.23
# 32   63408.86       129219.61         46085.25
# 33   55493.95       103057.49        214634.81
# 34   46426.07       157693.92        210797.67
# 35   46014.02        85047.44        205517.64
# 36   28663.76       127056.21        201126.82
# 37   44069.95        51283.14        197029.42
# 38   20229.59        65947.93        185265.10
# 39   38558.51        82982.09        174999.30
# 40   28754.33       118546.05        172795.67
# 41   27892.92        84710.77        164470.71
# 42   23640.93        96189.63        148001.11
# 43   15505.73       127382.30         35534.17
# 44   22177.74       154806.14         28334.72
# 45    1000.23       124153.04          1903.93
# 46    1315.46       115816.21        297114.46
# 47       0.00       135426.92             0.00
# 48     542.05        51743.15             0.00
# 49       0.00       116983.80         45173.06

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
#ora applico il modello su dati di test e train e li confornto. I dati di test sono dati che non ha mai
# visto
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression() #creo un modello con regressione lineare

# %%
model #creato ma senza valori
# Out:
# LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.25, 
                                                    random_state = 667
                                                    )

# %%
X_train.shape, X_test.shape
# Out:
# ((37, 3), (13, 3))

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
import pandas as pd
pd.DataFrame(list(zip(y_pred,y_test)))
# Out:
#                 0          1
# 0   112384.425342  122776.86
# 1   161765.882866  155752.60
# 2    95408.828106   97483.56
# 3   165953.452720  156991.12
# 4    43581.815368   64926.08
# 5    68476.739769   81229.06
# 6   192906.237511  191792.06
# 7   112059.158198  108552.04
# 8    73432.718357   78239.91
# 9   117516.423308  118474.03
# 10   61087.302145   65200.33
# 11  156346.509831  149759.96
# 12  115983.479377  105008.31

# %%
res_df = pd.DataFrame(data=list(zip(y_pred, y_test)),columns=['predicted', 'real'])
res_df
# Out:
#         predicted       real
# 0   112384.425342  122776.86
# 1   161765.882866  155752.60
# 2    95408.828106   97483.56
# 3   165953.452720  156991.12
# 4    43581.815368   64926.08
# 5    68476.739769   81229.06
# 6   192906.237511  191792.06
# 7   112059.158198  108552.04
# 8    73432.718357   78239.91
# 9   117516.423308  118474.03
# 10   61087.302145   65200.33
# 11  156346.509831  149759.96
# 12  115983.479377  105008.31

# %%
res_df['error'] = res_df['real'] - res_df['predicted']
res_df
# Out:
#         predicted       real         error
# 0   112384.425342  122776.86  10392.434658
# 1   161765.882866  155752.60  -6013.282866
# 2    95408.828106   97483.56   2074.731894
# 3   165953.452720  156991.12  -8962.332720
# 4    43581.815368   64926.08  21344.264632
# 5    68476.739769   81229.06  12752.320231
# 6   192906.237511  191792.06  -1114.177511
# 7   112059.158198  108552.04  -3507.118198
# 8    73432.718357   78239.91   4807.191643
# 9   117516.423308  118474.03    957.606692
# 10   61087.302145   65200.33   4113.027855
# 11  156346.509831  149759.96  -6586.549831
# 12  115983.479377  105008.31 -10975.169377

# %%
length = y_pred.shape[0] #  
x = np.linspace(0,length,length)

plt.figure(figsize=(10,7))
plt.plot(x, y_test, label='real y')
plt.plot(x, y_pred, label="predicted y'")
plt.legend(loc=2);
'''Il primo pezzo di codice assegna alla variabile "length" la lunghezza della prima dimensione dell'array "y_pred" (ovvero il numero di righe 
presenti nell'array).
Il secondo pezzo di codice crea un array di numeri equidistanti che ha come lunghezza proprio quella assegnata in precedenza alla variabile
 "length", e tale array viene poi assegnato alla variabile "x". In altre parole, "x" sarà un array di numeri che vanno da 0 a "length-1", 
 con passo 1.'''
# Out:
# 'Il primo pezzo di codice assegna alla variabile "length" la lunghezza della prima dimensione dell\'array "y_pred" (ovvero il numero di righe \npresenti nell\'array).\nIl secondo pezzo di codice crea un array di numeri equidistanti che ha come lunghezza proprio quella assegnata in precedenza alla variabile\n "length", e tale array viene poi assegnato alla variabile "x". In altre parole, "x" sarà un array di numeri che vanno da 0 a "length-1", \n con passo 1.'

# %%
#misuro l'errore del mio modello
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error 
r2score= r2_score(y_test, y_pred)
mae=mean_absolute_error(y_test, y_pred)
mse=mean_squared_error(y_test, y_pred)
rmse=mean_squared_error(y_test,y_pred,squared=False)

print('R2_score:', r2score)
print('MAE:',mae)
print('MSE:',mse)
print('RMSE',rmse)
# Out:
# R2_score: 0.9425062682580387
# MAE: 7200.016008322987
# MSE: 81946988.03279302
# RMSE 9052.457568682275

# %%
model.predict([[324,34,56]])[0] #faccio previsione con 3 dati di input sul modello creato
# Out:
# c:\Users\ifoa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 46463.38905163149

# %%
import joblib

## to save a model , salvo un modello in file pkl
joblib.dump(model,'regression_test.pkl')
# Out:
# ['regression_test.pkl']

# %%
## to load model, carico il modello 
newmodel = joblib.load('regression_test.pkl')
newmodel
# Out:
# LinearRegression()

# %%
newmodel.predict([[324,34,56]])[0] #faccio inferenza con il nuovo modello, ossia previsione inserendo 3 input
# Out:
# c:\Users\ifoa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 46463.38905163149
