# %%
from PIL import Image
img=Image.open('img/Cattura.JPG')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x537>

# %%
from PIL import Image
img1= Image.open('img/pastore tedesco.JPG') 
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=765x601>

# %%
pip list
# Out:
# Package               VersionNote: you may need to restart the kernel to use updated packages.
#
# --------------------- -----------
# altair                4.2.2
# asttokens             2.2.1
# attrs                 22.2.0
# backcall              0.2.0
# blinker               1.6.2
# cachetools            5.3.0
# certifi               2022.12.7
# charset-normalizer    3.1.0
# click                 8.1.3
# colorama              0.4.6
# comm                  0.1.3
# debugpy               1.6.7
# decorator             5.1.1
# entrypoints           0.4
# et-xmlfile            1.1.0
# executing             1.2.0
# gitdb                 4.0.10
# GitPython             3.1.31
# idna                  3.4
# importlib-metadata    6.3.0
# ipykernel             6.22.0
# ipython               8.12.1
# jedi                  0.18.2
# Jinja2                3.1.2
# jsonschema            4.17.3
# jupyter_client        8.2.0
# jupyter_core          5.3.0
# markdown-it-py        2.2.0
# ...

# %%
#
